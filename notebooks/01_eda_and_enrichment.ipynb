# %%
import pandas as pd
import numpy as np

# %%
df_main = pd.read_excel('../data/raw/ethiopia_fi_unified_data.xlsx', sheet_name='ethiopia_fi_unified_data')
df_impact = pd.read_excel('../data/raw/ethiopia_fi_unified_data.xlsx', sheet_name='Impact_sheet')

# %%
# This will show the new Telebirr row you just saved!
display(df_main.tail(5))
print(f"Latest Date: {df_main['observation_date'].max()}")
# Out:
#        record_id  record_type        category pillar  \
# 40      EVT_0008        event  infrastructure    NaN
# 41      EVT_0009        event          policy    NaN
# 42      EVT_0010        event         pricing    NaN
# 43  OBS_2026_001  observation             NaN  USAGE
# 44  EVT_2025_001        event          policy    NaN
#
#                                  indicator    indicator_code  \
# 40  EthioPay Instant Payment System Launch      EVT_ETHIOPAY
# 41                 NFIS-II Strategy Launch         EVT_NFIS2
# 42       Safaricom Ethiopia Price Increase  EVT_SAFCOM_PRICE
# 43                    Telebirr Total Users      USG_MM_USERS
# 44  Fayda Digital ID Mandatory for Banking
#
#    indicator_direction  value_numeric   value_text   value_type  ...  \
# 40                 NaN            NaN     Launched  categorical  ...
# 41                 NaN            NaN     Launched  categorical  ...
# 42                 NaN            NaN  Implemented  categorical  ...
# ...

# %%
print("--- Record Counts ---")
print(df_main['record_type'].value_counts())
print("\n--- Pillar Distribution ---")
print(df_main['pillar'].value_counts())
print("\n--- Confidence Levels ---")
print(df_main['confidence'].value_counts())
# Out:
# --- Record Counts ---
# record_type
# observation    31
# event          11
# target          3
# Name: count, dtype: int64
#
# --- Pillar Distribution ---
# pillar
# ACCESS           16
# USAGE            12
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64
#
# --- Confidence Levels ---
# confidence
# high      40
# medium     3
# High       2
# Name: count, dtype: int64

# %%
# Join Impact_sheet with event records
impact_analysis = df_impact.merge(
    df_main[df_main['record_type'] == 'event'][['record_id', 'indicator']], 
    left_on='parent_id', 
    right_on='record_id',
    suffixes=('_link', '_event')
)

print("--- Impact Links Verified ---")
display(impact_analysis[['indicator_event', 'related_indicator', 'impact_direction', 'impact_magnitude']].head())
# Out:
# --- Impact Links Verified ---
#                         indicator_event   related_indicator impact_direction  \
# 0                       Telebirr Launch       ACC_OWNERSHIP         increase
# 1                       Telebirr Launch  USG_TELEBIRR_USERS         increase
# 2                       Telebirr Launch       USG_P2P_COUNT         increase
# 3  Safaricom Ethiopia Commercial Launch          ACC_4G_COV         increase
# 4  Safaricom Ethiopia Commercial Launch     AFF_DATA_INCOME         decrease
#
#   impact_magnitude
# 0             high
# 1             high
# 2             high
# 3           medium
# 4           medium
